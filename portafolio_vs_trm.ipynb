# %% [markdown]
# # Portafolio vs TRM — cuenta Alejo
#
# eToro · agosto 2023 – 21 septiembre 2026
#
# El peso se revalorizó (TRM de ~4.030 a 3.193). El portafolio, en pesos, sigue positivo.
#
# | | USD | COP |
# |---|---|---|
# | Valor hoy | **$50.209** | **$160 M** |
# | Neto invertido | **$29.674** | **$117 M** |
# | Retorno simple | **+69,2%** | **+37,4%** |
# | XIRR | **30,7%** | **17,6%** |
#
# `(1 + r COP) = (1 + r USD) × (1 + r FX)`

# %% [markdown]
# ## Dólares vs neto invertido
#
# ![USD](images/usd_vs_trm.svg)

# %% [markdown]
# ## Pesos
#
# En 2026 el peso se fortalece: el valor en COP se aplana aunque el USD sigue subiendo. El FX restó. No eliminó el resultado.
#
# ![COP](images/cop.svg)

# %% [markdown]
# ## Notas
#
# - Valor hoy: captura eToro History 5Y del 21-sep-2026 ($50.208,72 y +69,20%).
# - Neto invertido: $50.209 / 1,6920 = $29.674.
# - Curva verde: proxy DCA (SPYG, SMH, IEMG, BRK.B, VTI) anclado al saldo real.
# - TRM oficial Superintendencia Financiera.
# - Solo cuenta Alejo. Sin Cindy ni Hapi.
#
# Rentabilidades pasadas no garantizan resultados futuros. No es recomendación de inversión.
